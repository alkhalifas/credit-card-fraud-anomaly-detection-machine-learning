# %% [markdown]
# ## Credit Card Fraud/Anomaly Detection (DecisionTrees, CNNs, and ANNs)

# %% [markdown]
# ##### About the Data:

# %% [markdown]
# The datasets contains transactions made by credit cards in September 2013 by european cardholders.
# This dataset presents transactions that occurred in two days, where we have 492 frauds out of 284,807 transactions. The dataset is highly unbalanced, the positive class (frauds) account for 0.172% of all transactions.
#
# It contains only numerical input variables which are the result of a PCA transformation. Unfortunately, due to confidentiality issues, we cannot provide the original features and more background information about the data. Features V1, V2, … V28 are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and 'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset. The feature 'Amount' is the transaction Amount, this feature can be used for example-dependant cost-senstive learning. Feature 'Class' is the response variable and it takes value 1 in case of fraud and 0 otherwise.

# %% [markdown]
# ##### Objective:

# %% [markdown]
# To develop a classification model that can identify, with high certainty, whether a transaction is fradulent or not given the current dataset.

# %% [markdown]
# ### 1. Import Libraries:

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("darkgrid")

# %% [markdown]
# ### 2. Import Data:

# %%
df = pd.read_csv("./data/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.139097 -0.055353 -0.059752  378.66      0
# 3 -0.221929  0.062723  0.061458  123.50      0
# 4  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ### 3. Exploratory Data Analysis:

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# std    1.380247e+00  1.332271e+00  1.237094e+00  1.194353e+00  1.098632e+00
# min   -1.137433e+02 -2.616051e+01 -4.355724e+01 -7.321672e+01 -1.343407e+01
# 25%   -6.915971e-01 -7.682956e-01 -5.540759e-01 -2.086297e-01 -6.430976e-01
# 50%   -5.433583e-02 -2.741871e-01  4.010308e-02  2.235804e-02 -5.142873e-02
# 75%    6.119264e-01  3.985649e-01  5.704361e-01  3.273459e-01  5.971390e-01
# max    3.480167e+01  7.330163e+01  1.205895e+02  2.000721e+01  1.559499e+01
#
#        ...           V21           V22           V23           V24  \
# count  ...  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   ...  1.537294e-16  7.959909e-16  5.367590e-16  4.458112e-15
# std    ...  7.345240e-01  7.257016e-01  6.244603e-01  6.056471e-01
# min    ... -3.483038e+01 -1.093314e+01 -4.480774e+01 -2.836627e+00
# 25%    ... -2.283949e-01 -5.423504e-01 -1.618463e-01 -3.545861e-01
# 50%    ... -2.945017e-02  6.781943e-03 -1.119293e-02  4.097606e-02
# 75%    ...  1.863772e-01  5.285536e-01  1.476421e-01  4.395266e-01
# max    ...  2.720284e+01  1.050309e+01  2.252841e+01  4.584549e+00
#
#                 V25           V26           V27           V28         Amount  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  284807.000000
# mean   1.453003e-15  1.699104e-15 -3.660161e-16 -1.206049e-16      88.349619
# std    5.212781e-01  4.822270e-01  4.036325e-01  3.300833e-01     250.120109
# min   -1.029540e+01 -2.604551e+00 -2.256568e+01 -1.543008e+01       0.000000
# 25%   -3.171451e-01 -3.269839e-01 -7.083953e-02 -5.295979e-02       5.600000
# 50%    1.659350e-02 -5.213911e-02  1.342146e-03  1.124383e-02      22.000000
# 75%    3.507156e-01  2.409522e-01  9.104512e-02  7.827995e-02      77.165000
# max    7.519589e+00  3.517346e+00  3.161220e+01  3.384781e+01   25691.160000
#
#                Class
# count  284807.000000
# mean        0.001727
# std         0.041527
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
#
# [8 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
#  20  V20     284807 non-null  float64
#  21  V21     284807 non-null  float64
#  22  V22     284807 non-null  float64
#  23  V23     284807 non-null  float64
#  24  V24     284807 non-null  float64
#  25  V25     284807 non-null  float64
#  26  V26     284807 non-null  float64
#  27  V27     284807 non-null  float64
#  28  V28     284807 non-null  float64
#  29  Amount  284807 non-null  float64
#  30  Class   284807 non-null  int64
# dtypes: float64(30), int64(1)
# memory usage: 67.4 MB

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df.Class.value_counts()
# 0 = Valid
# 1 = Fraud
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
df.hist(figsize=(15,15));

# %%
plt.figure(figsize=(20,10))
sns.pairplot(df[["Time","V1", "Amount"]])

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(df["Time"], df["V1"], hue=df["Class"])

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(df["V1"], df["V2"], hue=df["Class"])

# %% [markdown]
# ### 4. Preprocessing:

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X = df.iloc[:, :-1]
y = df.Class.values.ravel()

X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ###  5. Split Training and Testing Data:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (213605, 30)
# (71202, 30)
# (213605,)
# (71202,)

# %% [markdown]
# ### 6. Model Development

# %% [markdown]
# #### Random Forests Classification:

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71089
#            1       0.94      0.79      0.86       113
#
#     accuracy                           1.00     71202
#    macro avg       0.97      0.89      0.93     71202
# weighted avg       1.00      1.00      1.00     71202

# %% [markdown]
# #### XGBoost Classification:

# %%
from xgboost import XGBClassifier

xgb = XGBClassifier()
xgb.fit(X_train, y_train)
y_pred = xgb.predict(X_test)

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71089
#            1       0.91      0.80      0.85       113
#
#     accuracy                           1.00     71202
#    macro avg       0.95      0.90      0.92     71202
# weighted avg       1.00      1.00      1.00     71202

# %% [markdown]
# #### Artificial Neural Network using Keras:

# %%
from tensorflow import keras
print(keras.__version__)
# Out:
# 2.2.4-tf

# %%
model = keras.Sequential(
    [
        keras.layers.Dense(32, activation="relu", input_shape=(X_train.shape[-1],)),
        keras.layers.Dense(128, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                992
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               4224
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 38,497
# Trainable params: 38,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=keras.optimizers.Adam(1e-2), loss="binary_crossentropy", metrics=["accuracy"]
)

# %%
history = model.fit(
                    X_train,
                    y_train,
                    batch_size=2048,
                    epochs=30,
                    verbose=2,
                    validation_split = 0.2,
)
# Out:
# Train on 170884 samples, validate on 42721 samples
# Epoch 1/30
# 170884/170884 - 3s - loss: 54.3937 - accuracy: 0.9889 - val_loss: 0.0399 - val_accuracy: 0.9982
# Epoch 2/30
# 170884/170884 - 2s - loss: 0.3157 - accuracy: 0.9954 - val_loss: 0.0682 - val_accuracy: 0.9982
# Epoch 3/30
# 170884/170884 - 2s - loss: 0.1824 - accuracy: 0.9971 - val_loss: 0.0765 - val_accuracy: 0.9982
# Epoch 4/30
# 170884/170884 - 2s - loss: 0.1629 - accuracy: 0.9969 - val_loss: 0.0211 - val_accuracy: 0.9982
# Epoch 5/30
# 170884/170884 - 2s - loss: 0.0978 - accuracy: 0.9982 - val_loss: 0.0190 - val_accuracy: 0.9982
# Epoch 6/30
# 170884/170884 - 2s - loss: 0.0429 - accuracy: 0.9982 - val_loss: 0.0176 - val_accuracy: 0.9982
# Epoch 7/30
# 170884/170884 - 2s - loss: 0.0489 - accuracy: 0.9980 - val_loss: 0.0157 - val_accuracy: 0.9982
# Epoch 8/30
# 170884/170884 - 2s - loss: 0.0533 - accuracy: 0.9982 - val_loss: 0.0160 - val_accuracy: 0.9982
# Epoch 9/30
# 170884/170884 - 2s - loss: 0.0328 - accuracy: 0.9982 - val_loss: 0.0163 - val_accuracy: 0.9982
# Epoch 10/30
# 170884/170884 - 2s - loss: 0.0246 - accuracy: 0.9982 - val_loss: 0.0149 - val_accuracy: 0.9982
# Epoch 11/30
# 170884/170884 - 2s - loss: 0.0296 - accuracy: 0.9982 - val_loss: 0.0152 - val_accuracy: 0.9982
# Epoch 12/30
# 170884/170884 - 2s - loss: 0.0231 - accuracy: 0.9982 - val_loss: 0.0144 - val_accuracy: 0.9982
# Epoch 13/30
# 170884/170884 - 2s - loss: 0.0863 - accuracy: 0.9982 - val_loss: 0.0140 - val_accuracy: 0.9982
# Epoch 14/30
# 170884/170884 - 2s - loss: 0.0235 - accuracy: 0.9979 - val_loss: 0.0139 - val_accuracy: 0.9982
# Epoch 15/30
# 170884/170884 - 2s - loss: 0.0245 - accuracy: 0.9982 - val_loss: 0.0137 - val_accuracy: 0.9982
# Epoch 16/30
# 170884/170884 - 2s - loss: 0.0164 - accuracy: 0.9982 - val_loss: 0.0139 - val_accuracy: 0.9982
# Epoch 17/30
# 170884/170884 - 2s - loss: 0.0167 - accuracy: 0.9982 - val_loss: 0.0152 - val_accuracy: 0.9982
# Epoch 18/30
# 170884/170884 - 2s - loss: 0.0213 - accuracy: 0.9982 - val_loss: 0.0141 - val_accuracy: 0.9982
# Epoch 19/30
# 170884/170884 - 2s - loss: 0.0148 - accuracy: 0.9982 - val_loss: 0.0138 - val_accuracy: 0.9982
# Epoch 20/30
# 170884/170884 - 2s - loss: 0.0151 - accuracy: 0.9982 - val_loss: 0.0136 - val_accuracy: 0.9982
# Epoch 21/30
# 170884/170884 - 2s - loss: 0.0445 - accuracy: 0.9976 - val_loss: 0.0147 - val_accuracy: 0.9982
# Epoch 22/30
# 170884/170884 - 2s - loss: 0.0268 - accuracy: 0.9982 - val_loss: 0.0143 - val_accuracy: 0.9982
# Epoch 23/30
# 170884/170884 - 2s - loss: 0.0192 - accuracy: 0.9982 - val_loss: 0.0140 - val_accuracy: 0.9982
# Epoch 24/30
# 170884/170884 - 2s - loss: 0.0144 - accuracy: 0.9982 - val_loss: 0.0139 - val_accuracy: 0.9982
# Epoch 25/30
# 170884/170884 - 2s - loss: 0.0157 - accuracy: 0.9982 - val_loss: 0.0138 - val_accuracy: 0.9982
# Epoch 26/30
# 170884/170884 - 2s - loss: 0.0137 - accuracy: 0.9982 - val_loss: 0.0137 - val_accuracy: 0.9982
# Epoch 27/30
# 170884/170884 - 2s - loss: 0.0133 - accuracy: 0.9982 - val_loss: 0.0136 - val_accuracy: 0.9982
# Epoch 28/30
# 170884/170884 - 2s - loss: 0.0152 - accuracy: 0.9982 - val_loss: 0.0136 - val_accuracy: 0.9982
# Epoch 29/30
# 170884/170884 - 2s - loss: 0.0133 - accuracy: 0.9982 - val_loss: 0.0135 - val_accuracy: 0.9982
# Epoch 30/30
# 170884/170884 - 2s - loss: 0.0135 - accuracy: 0.9982 - val_loss: 0.0135 - val_accuracy: 0.9982

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
results = pd.DataFrame(history.history)
results.head(5)
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0  54.393719  0.988916  0.039903      0.998151
# 1   0.315725  0.995400  0.068241      0.998151
# 2   0.182378  0.997109  0.076501      0.998151
# 3   0.162885  0.996945  0.021141      0.998151
# 4   0.097827  0.998221  0.018974      0.998151

# %%
plt.figure(figsize = (15,4))

plt.subplot(121)
plt.plot(results.index, results.accuracy, label="Training Accuracy")
plt.plot(results.index, results.val_accuracy, label="Validation Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy Score")
plt.title("Training and Validation Accuracy over Epochs" )

plt.subplot(122)
plt.plot(results.index, results.loss, label="Training Loss")
plt.plot(results.index, results.val_loss, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Accuracy Score")
plt.title("Training and Validation Loss over Epochs" )
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss over Epochs')

# %% [markdown]
# #### Artificial Neural Network using Keras with Metrics & Weights:

# %%
counts = np.bincount(y_train)
wt_0 = 1.0 / counts[0]
wt_1 = 1.0 / counts[1]

print(wt_0)
print(wt_1)
# Out:
# 4.689859585604007e-06
# 0.002638522427440633

# %%
model = keras.Sequential(
    [
        keras.layers.Dense(
            256, activation="relu", input_shape=(X_train.shape[-1],)
        ),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(256, activation="relu"),
        keras.layers.Dropout(0.3),
        keras.layers.Dense(1, activation="sigmoid"),
    ]
)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 256)               7936
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 139,777
# Trainable params: 139,777
# Non-trainable params: 0
# _________________________________________________________________

# %%
metrics = [
    keras.metrics.Precision(name="precision"),
#     keras.metrics.Recall(name="recall"),
#     keras.metrics.Accuracy(name="accuracy")
]

model.compile(
    optimizer=keras.optimizers.Adam(1e-2), loss="binary_crossentropy", metrics=metrics
)



history = model.fit(
                    X_train,
                    y_train,
                    batch_size=2048,
                    epochs=30,
                    verbose=2,
                    validation_split = 0.2,
                    class_weight = {0: wt_0, 1: wt_1}
)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train on 170884 samples, validate on 42721 samples
# Epoch 1/30
# 170884/170884 - 4s - loss: 0.0106 - precision: 0.0018 - val_loss: 6.6510e-06 - val_precision: 0.0018
# Epoch 2/30
# 170884/170884 - 3s - loss: 6.4979e-06 - precision: 0.0018 - val_loss: 6.7072e-06 - val_precision: 0.0018
# Epoch 3/30
# 170884/170884 - 4s - loss: 6.7972e-06 - precision: 0.0017 - val_loss: 6.7145e-06 - val_precision: 0.0000e+00
# Epoch 4/30
# 170884/170884 - 3s - loss: 6.9191e-06 - precision: 0.0017 - val_loss: 6.6266e-06 - val_precision: 0.0000e+00
# Epoch 5/30
# 170884/170884 - 3s - loss: 2.1797e-05 - precision: 0.0016 - val_loss: 6.6331e-06 - val_precision: 0.0000e+00
# Epoch 6/30
# 170884/170884 - 3s - loss: 6.4577e-06 - precision: 0.0015 - val_loss: 6.6299e-06 - val_precision: 0.0000e+00
# Epoch 7/30
# 170884/170884 - 3s - loss: 6.4531e-06 - precision: 0.0015 - val_loss: 6.6299e-06 - val_precision: 0.0000e+00
# Epoch 8/30
# 170884/170884 - 3s - loss: 6.4591e-06 - precision: 0.0018 - val_loss: 6.6299e-06 - val_precision: 0.0018
# Epoch 9/30
# 170884/170884 - 3s - loss: 6.4513e-06 - precision: 0.0018 - val_loss: 6.6302e-06 - val_precision: 0.0000e+00
# Epoch 10/30
# 170884/170884 - 3s - loss: 6.5046e-06 - precision: 0.0017 - val_loss: 6.6279e-06 - val_precision: 0.0000e+00
# Epoch 11/30
# 170884/170884 - 3s - loss: 6.4597e-06 - precision: 0.0019 - val_loss: 6.6266e-06 - val_precision: 0.0018
# Epoch 12/30
# 170884/170884 - 3s - loss: 7.1941e-06 - precision: 0.0016 - val_loss: 6.6278e-06 - val_precision: 0.0000e+00
# Epoch 13/30
# 170884/170884 - 3s - loss: 6.4614e-06 - precision: 0.0000e+00 - val_loss: 6.6273e-06 - val_precision: 0.0000e+00
# Epoch 14/30
# 170884/170884 - 3s - loss: 6.4586e-06 - precision: 0.0016 - val_loss: 6.6262e-06 - val_precision: 0.0018
# Epoch 15/30
# 170884/170884 - 3s - loss: 6.4606e-06 - precision: 0.0016 - val_loss: 6.6260e-06 - val_precision: 0.0018
# Epoch 16/30
# 170884/170884 - 3s - loss: 6.4590e-06 - precision: 0.0017 - val_loss: 6.6292e-06 - val_precision: 0.0000e+00
# Epoch 17/30
# 170884/170884 - 3s - loss: 6.4640e-06 - precision: 0.0017 - val_loss: 6.6278e-06 - val_precision: 0.0000e+00
# Epoch 18/30
# 170884/170884 - 3s - loss: 6.4586e-06 - precision: 0.0000e+00 - val_loss: 6.6287e-06 - val_precision: 0.0000e+00
# Epoch 19/30
# 170884/170884 - 3s - loss: 6.4606e-06 - precision: 0.0000e+00 - val_loss: 6.6286e-06 - val_precision: 0.0000e+00
# Epoch 20/30
# 170884/170884 - 3s - loss: 6.4614e-06 - precision: 0.0016 - val_loss: 6.6252e-06 - val_precision: 0.0018
# Epoch 21/30
# 170884/170884 - 3s - loss: 6.4579e-06 - precision: 0.0017 - val_loss: 6.6275e-06 - val_precision: 0.0000e+00
# Epoch 22/30
# 170884/170884 - 3s - loss: 6.4605e-06 - precision: 0.0015 - val_loss: 6.6290e-06 - val_precision: 0.0000e+00
# Epoch 23/30
# 170884/170884 - 3s - loss: 6.4637e-06 - precision: 0.0016 - val_loss: 6.6307e-06 - val_precision: 0.0000e+00
# Epoch 24/30
# 170884/170884 - 4s - loss: 6.4583e-06 - precision: 0.0015 - val_loss: 6.6289e-06 - val_precision: 0.0000e+00
# Epoch 25/30
# 170884/170884 - 3s - loss: 6.4601e-06 - precision: 0.0017 - val_loss: 6.6258e-06 - val_precision: 0.0018
# Epoch 26/30
# 170884/170884 - 3s - loss: 6.4608e-06 - precision: 0.0017 - val_loss: 6.6323e-06 - val_precision: 0.0000e+00
# Epoch 27/30
# 170884/170884 - 3s - loss: 6.4590e-06 - precision: 0.0000e+00 - val_loss: 6.6277e-06 - val_precision: 0.0000e+00
# Epoch 28/30
# 170884/170884 - 3s - loss: 6.4581e-06 - precision: 0.0017 - val_loss: 6.6258e-06 - val_precision: 0.0018
# Epoch 29/30
# 170884/170884 - 4s - loss: 6.4629e-06 - precision: 0.0015 - val_loss: 6.6283e-06 - val_precision: 0.0000e+00
# Epoch 30/30
# 170884/170884 - 3s - loss: 6.4624e-06 - precision: 0.0016 - val_loss: 6.6285e-06 - val_precision: 0.0000e+00

# %%
score = model.evaluate(X_test, y_test)
# Out:
# 71202/71202 [==============================] - 3s 43us/sample - loss: 0.6858 - precision: 0.0000e+00

# %% [markdown]
# #### Convolutional Neural Network using Keras with Metrics & Weights:

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout, BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import TensorBoard

# %%
X_train.shape[-1]
# Out:
# 30

# %%
X_test_d = np.expand_dims(X_test, -1)
X_train_d  = np.expand_dims(X_train, -1)

# %%
model = Sequential()
model.add(Conv1D(32, 2, activation='relu', input_shape=X_test_d[0].shape))
model.add(BatchNormalization())
model.add(Dropout(0.1))

model.add(Conv1D(64, 2, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Conv1D(128, 2, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.3))

model.add(Flatten())
model.add(Dropout(0.4))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_18 (Conv1D)           (None, 29, 32)            96
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 29, 32)            128
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 29, 32)            0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 28, 64)            4160
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 28, 64)            256
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 28, 64)            0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 27, 128)           16512
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 27, 128)           512
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 27, 128)           0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 3456)              0
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 3456)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               1769984
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 1,792,161
# Trainable params: 1,791,713
# Non-trainable params: 448
# _________________________________________________________________

# %%
METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=METRICS)
r = model.fit(X_train_d, y_train, 
              validation_split=0.2,
              batch_size=16, 
              epochs=20, 
             )
# Out:
# Train on 170884 samples, validate on 42721 samples
# Epoch 1/20
# 170884/170884 [==============================] - 381s 2ms/step - loss: 0.0225 - accuracy: 0.9986 - precision: 0.5947 - recall: 0.5967 - val_loss: 0.0189 - val_accuracy: 0.9994 - val_precision: 0.8571 - val_recall: 0.8354
# Epoch 2/20
# 170884/170884 [==============================] - 405s 2ms/step - loss: 0.0159 - accuracy: 0.9988 - precision: 0.6899 - recall: 0.5933 - val_loss: 0.0098 - val_accuracy: 0.9993 - val_precision: 0.8551 - val_recall: 0.7468
# Epoch 3/20
# 170884/170884 [==============================] - 406s 2ms/step - loss: 0.0124 - accuracy: 0.9990 - precision: 0.7452 - recall: 0.6533 - val_loss: 0.0133 - val_accuracy: 0.9994 - val_precision: 0.8553 - val_recall: 0.8228
# Epoch 4/20
# 170884/170884 [==============================] - 404s 2ms/step - loss: 0.0096 - accuracy: 0.9991 - precision: 0.7738 - recall: 0.6500 - val_loss: 0.0079 - val_accuracy: 0.9994 - val_precision: 0.8442 - val_recall: 0.8228
# Epoch 5/20
# 170884/170884 [==============================] - 408s 2ms/step - loss: 0.0074 - accuracy: 0.9990 - precision: 0.7890 - recall: 0.6233 - val_loss: 0.0072 - val_accuracy: 0.9994 - val_precision: 0.8533 - val_recall: 0.8101
# Epoch 6/20
# 170884/170884 [==============================] - 415s 2ms/step - loss: 0.0064 - accuracy: 0.9992 - precision: 0.8478 - recall: 0.6500 - val_loss: 0.0050 - val_accuracy: 0.9994 - val_precision: 0.8514 - val_recall: 0.7975
# Epoch 7/20
# 170884/170884 [==============================] - 401s 2ms/step - loss: 0.0065 - accuracy: 0.9991 - precision: 0.8210 - recall: 0.6267 - val_loss: 0.0049 - val_accuracy: 0.9994 - val_precision: 0.8571 - val_recall: 0.8354
# Epoch 8/20
#  93648/170884 [===============>..............] - ETA: 2:35 - loss: 0.0070 - accuracy: 0.9992 - precision: 0.8197 - recall: 0.6452

# %%
score = model.evaluate(X_test, y_test)
